# %%
# %%bash
#
# pip install pip --upgrade pip
# pip install --no-cache-dir . > /dev/null
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 1.4 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1
#     Uninstalling pip-24.1:
#       Successfully uninstalled pip-24.1
# ...

# %%
import sys

# %%
sys.argv = [
'script.py',
'--input_path', '/home/bruno/storage/data/fma/trains/rock_electronic',
'--output_path', '/home/bruno/storage/data/fma/trains/rock_electronic/jobs',
'--batch_size', '128',
'--epochs', '20',
'--dropout', '0.3', '0.3', '0.3', '0.3',
'--patience', '5'
]

# %%
from hmc import run

# %%
run()
# Out:
# ========================= PyTorch =========================
# GPUs available: 1
# ...
# Job ID: 20240911_142342
# Epoch 1/20
# train Loss 0.685 for level 0
# train Loss 0.658 for level 1
# train Loss 0.603 for level 2
# train Loss 0.515 for level 3
# Global train Loss: 0.615
# Epoch 1/20
# val Loss 0.680 for level 0
# val Loss 0.611 for level 1
# val Loss 0.491 for level 2
# val Loss 0.327 for level 3
# Global val Loss: 4.479
# Epoch 2/20
# train Loss 0.681 for level 0
# train Loss 0.539 for level 1
# train Loss 0.362 for level 2
# train Loss 0.219 for level 3
# Global train Loss: 0.450
# Epoch 2/20
# val Loss 0.679 for level 0
# val Loss 0.449 for level 1
# val Loss 0.254 for level 2
# val Loss 0.149 for level 3
# Global val Loss: 3.251
# Epoch 3/20
# train Loss 0.681 for level 0
# train Loss 0.356 for level 1
# train Loss 0.206 for level 2
# train Loss 0.115 for level 3
# Global train Loss: 0.340
# Epoch 3/20
# val Loss 0.679 for level 0
# val Loss 0.271 for level 1
# ...
